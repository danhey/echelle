# %%
import numpy as np
import matplotlib 
# %matplotlib notebook
# import sys 
# sys.path.append('/Volumes/Data/Onedrive/github/echelle')
from echelle import interact_echelle

data = np.load('data/snr.npy')
freq, power = data[:,0], data[:,1]
idx = (freq>100) & (freq<600)
freq, power = freq[idx], power[idx]
interact_echelle(freq, power, 10, 50, smooth=True, replicated=True, p_modes_asymp=True, mixed_modes_asymp=True, dpi_min=10, dpi_max=200)
# Out:
# <img src="data:image/png;base64,..." width="1200">
