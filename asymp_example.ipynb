# %%
import numpy as np
import matplotlib 
# %matplotlib notebook
from echelle_test import interact_echelle

data = np.load('20200422/007341231_slc_mwg1_psd.npy')
freq, power = data[:,0], data[:,1]
idx = (freq>200) & (freq<600)
freq, power = freq[idx], power[idx]
interact_echelle(freq, power, 10, 50, smooth=True, p_modes_asymp=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
data = np.load('20200422/003429205_slc_mwg1_psd.npy')
freq, power = data[:,0], data[:,1]
idx = (freq>250) & (freq<500)
freq, power = freq[idx], power[idx]
interact_echelle(freq, power, 10, 50, smooth=True, p_modes_asymp=True, mixed_modes_asymp=True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
(1/346 - 1/(319+21))*1e6
# Out:
# -51.00306018361112
